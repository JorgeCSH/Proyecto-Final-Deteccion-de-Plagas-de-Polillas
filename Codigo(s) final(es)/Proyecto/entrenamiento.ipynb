# %% [markdown]
# <a href="https://colab.research.google.com/github/JorgeCSH/Proyecto-Final-Deteccion-de-Plagas-de-Polillas/blob/main/entrenamiento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Deteccion de polillas

# %% [markdown]
# # Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import files
files.download("/content/weights.zip")

# %% [markdown]
# # Instalacion YoloV8

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.2/78.2 GB disk)

# %% [markdown]
# # Entrenamiento

# %%
import os
import sys
os.environ["PYTHONPATH"]="/content/drive/MyDrive/YOLOv8"

# Modelo m, 30 epocas
#!yolo train model=yolov8m.pt data=/content/drive/MyDrive/Datasets/YOLODataset/dataset.yaml epochs=100 imgsz=640 conf=0.5
# Modelo x, 30 epocas
# !yolo train model=yolov8m.pt data=/content/drive/MyDrive/Datasets/YOLODataset/dataset.yaml epochs=30 imgsz=640 optimizer=Adamax
# Modelo m, 200 epocas

#Modelo x, 200 epocas
# Out:
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# engine/trainer: task=detect, mode=train, model=yolov8m.pt, data=/content/drive/MyDrive/Datasets/YOLODataset/dataset.yaml, epochs=30, patience=50, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train5, exist_ok=False, pretrained=True, optimizer=Adamax, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train5
# 2023-12-15 01:57:06.820077: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-15 01:57:06.820133: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-15 01:57:06.821611: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.conv.Conv             [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1   1991808  ultralytics.nn.modules.conv.Conv             [384, 576, 3, 2]
#   8                  -1  2   3985920  ultralytics.nn.modules.block.C2f             [576, 576, 2, True]
#   9                  -1  1    831168  ultralytics.nn.modules.block.SPPF            [576, 576, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  2   1993728  ultralytics.nn.modules.block.C2f             [960, 384, 2]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  2    517632  ultralytics.nn.modules.block.C2f             [576, 192, 2]
#  16                  -1  1    332160  ultralytics.nn.modules.conv.Conv             [192, 192, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  2   1846272  ultralytics.nn.modules.block.C2f             [576, 384, 2]
#  19                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  2   4207104  ultralytics.nn.modules.block.C2f             [960, 576, 2]
#  22        [15, 18, 21]  1   3776275  ultralytics.nn.modules.head.Detect           [1, [192, 384, 576]]
# Model summary: 295 layers, 25856899 parameters, 25856883 gradients, 79.1 GFLOPs
#
# Transferred 469/475 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train5', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning /content/drive/.shortcut-targets-by-id/14Rr-D0WcF7o-G-p0mjLIi3N56cCwJE4X/Datasets/YOLODataset/labels/train.cache... 136 images, 1 backgrounds, 0 corrupt: 100% 136/136 [00:00<?, ?it/s]
# train: WARNING ⚠️ /content/drive/.shortcut-targets-by-id/14Rr-D0WcF7o-G-p0mjLIi3N56cCwJE4X/Datasets/YOLODataset/images/train/0095.png: 4 duplicate labels removed
# train: WARNING ⚠️ /content/drive/.shortcut-targets-by-id/14Rr-D0WcF7o-G-p0mjLIi3N56cCwJE4X/Datasets/YOLODataset/images/train/0096.png: 7 duplicate labels removed
# train: WARNING ⚠️ /content/drive/.shortcut-targets-by-id/14Rr-D0WcF7o-G-p0mjLIi3N56cCwJE4X/Datasets/YOLODataset/images/train/0098.png: 1 duplicate labels removed
# train: WARNING ⚠️ /content/drive/.shortcut-targets-by-id/14Rr-D0WcF7o-G-p0mjLIi3N56cCwJE4X/Datasets/YOLODataset/images/train/0132.png: 1 duplicate labels removed
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/drive/.shortcut-targets-by-id/14Rr-D0WcF7o-G-p0mjLIi3N56cCwJE4X/Datasets/YOLODataset/labels/val.cache... 33 images, 0 backgrounds, 0 corrupt: 100% 33/33 [00:00<?, ?it/s]
# Plotting labels to runs/detect/train5/labels.jpg...
# optimizer: Adamax(lr=0.01, momentum=0.937) with parameter groups 77 weight(decay=0.0), 84 weight(decay=0.0005), 83 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/detect/train5
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/30      6.81G      2.665      8.691      1.316        243        640: 100% 9/9 [00:27<00:00,  3.08s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:03<00:00,  1.63s/it]
#                    all         33        474     0.0815       0.58     0.0893     0.0274
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/30      7.31G       2.66      12.39      1.282        254        640: 100% 9/9 [00:15<00:00,  1.70s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:00<00:00,  3.87it/s]
#                    all         33        474     0.0815       0.58     0.0893     0.0274
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/30      7.29G      2.182       1.89      1.187        140        640: 100% 9/9 [00:10<00:00,  1.20s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:00<00:00,  3.62it/s]
#                    all         33        474     0.0815       0.58     0.0893     0.0274
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/30      7.49G      2.063      1.607      1.126        157        640: 100% 9/9 [00:07<00:00,  1.17it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:00<00:00,  3.74it/s]
#                    all         33        474     0.0815       0.58     0.0893     0.0274
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/30      7.55G      2.044      1.403      1.076        277        640: 100% 9/9 [00:10<00:00,  1.12s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.39it/s]
#                    all         33        474     0.0815       0.58     0.0893     0.0274
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/30      7.31G      1.968      1.298      1.093        139        640: 100% 9/9 [00:06<00:00,  1.31it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.29it/s]
#                    all         33        474   0.000512     0.0105    0.00026   6.72e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/30      7.03G      1.941      1.264      1.095        188        640: 100% 9/9 [00:09<00:00,  1.10s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.26it/s]
#                    all         33        474   0.000303    0.00633   0.000154   5.18e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/30      7.31G       1.85       1.26      1.052        228        640: 100% 9/9 [00:07<00:00,  1.17it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.61it/s]
#                    all         33        474   0.000202    0.00422   0.000105   1.05e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/30      7.34G      1.992       1.23       1.09        130        640: 100% 9/9 [00:08<00:00,  1.10it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.48it/s]
#                    all         33        474   0.000101    0.00211   5.07e-05   5.07e-06
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/30      7.59G      1.918      1.229      1.047        241        640: 100% 9/9 [00:10<00:00,  1.12s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.80it/s]
#                    all         33        474   0.000101    0.00211   5.07e-05   5.07e-06
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/30      7.39G      1.875      1.215      1.045        213        640: 100% 9/9 [00:09<00:00,  1.03s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.65it/s]
#                    all         33        474   0.000614     0.0127   0.000307   7.64e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/30      6.87G      1.902      1.197      1.028        296        640: 100% 9/9 [00:08<00:00,  1.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.28it/s]
#                    all         33        474   0.000202    0.00422   0.000103   3.08e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/30      7.61G      1.879      1.206      1.041        116        640: 100% 9/9 [00:08<00:00,  1.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.48it/s]
#                    all         33        474    0.00177     0.0359   0.000891   0.000239
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/30      7.28G        1.9      1.111      1.041        220        640: 100% 9/9 [00:08<00:00,  1.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.70it/s]
#                    all         33        474      0.364      0.565      0.376      0.152
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/30      7.35G      1.901      1.165      1.078        107        640: 100% 9/9 [00:09<00:00,  1.01s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.52it/s]
#                    all         33        474      0.552      0.618      0.535      0.184
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/30      7.28G      1.836      1.123      1.061        222        640: 100% 9/9 [00:09<00:00,  1.05s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.42it/s]
#                    all         33        474      0.609      0.517      0.482      0.216
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/30      7.28G      1.818      1.081      1.021        204        640: 100% 9/9 [00:08<00:00,  1.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.52it/s]
#                    all         33        474      0.609      0.734      0.667      0.295
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/30      7.31G      1.837      1.198      1.038        167        640: 100% 9/9 [00:12<00:00,  1.35s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:00<00:00,  2.10it/s]
#                    all         33        474      0.636      0.726       0.69      0.313
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/30      7.61G      1.859      1.129       1.05        123        640: 100% 9/9 [00:08<00:00,  1.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.78it/s]
#                    all         33        474      0.668      0.726      0.686      0.302
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/30      7.31G      1.817      1.113      1.015        140        640: 100% 9/9 [00:11<00:00,  1.29s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.83it/s]
#                    all         33        474      0.679      0.782      0.751       0.33
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/30      7.31G      1.822      1.199      1.055         78        640: 100% 9/9 [00:29<00:00,  3.28s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:00<00:00,  2.09it/s]
#                    all         33        474      0.713      0.817      0.803      0.365
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/30      7.34G      1.762      1.134      1.041         51        640: 100% 9/9 [00:10<00:00,  1.17s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:00<00:00,  2.54it/s]
#                    all         33        474       0.69      0.829      0.798      0.362
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/30      7.07G      1.819      1.092      1.037        173        640: 100% 9/9 [00:10<00:00,  1.11s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:00<00:00,  2.43it/s]
#                    all         33        474      0.684      0.833      0.766      0.341
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/30      7.32G      1.796       1.11      1.074         90        640: 100% 9/9 [00:08<00:00,  1.07it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:00<00:00,  2.32it/s]
#                    all         33        474      0.707      0.806      0.779      0.341
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/30       7.3G      1.768      1.075       1.06         75        640: 100% 9/9 [00:05<00:00,  1.66it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:00<00:00,  2.44it/s]
#                    all         33        474      0.701      0.842      0.778      0.357
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/30      7.33G      1.754      1.108      1.062        112        640: 100% 9/9 [00:06<00:00,  1.38it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  2.00it/s]
#                    all         33        474      0.691      0.847      0.776      0.348
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/30      7.29G      1.753      1.087      1.077        122        640: 100% 9/9 [00:06<00:00,  1.49it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:03<00:00,  1.88s/it]
#                    all         33        474      0.729      0.804      0.808      0.373
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/30      7.33G      1.726      1.062      1.061         50        640: 100% 9/9 [00:05<00:00,  1.77it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:02<00:00,  1.37s/it]
#                    all         33        474      0.728      0.795      0.812      0.376
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/30      7.28G      1.759      1.087      1.042        117        640: 100% 9/9 [00:05<00:00,  1.51it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:00<00:00,  2.26it/s]
#                    all         33        474      0.726      0.797      0.805      0.372
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/30      7.28G      1.763      1.031      1.046        113        640: 100% 9/9 [00:07<00:00,  1.29it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.27it/s]
#                    all         33        474       0.71       0.81      0.809      0.378
#
# 30 epochs completed in 0.148 hours.
# Optimizer stripped from runs/detect/train5/weights/last.pt, 52.0MB
# Optimizer stripped from runs/detect/train5/weights/best.pt, 52.0MB
#
# Validating runs/detect/train5/weights/best.pt...
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25840339 parameters, 0 gradients, 78.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.98it/s]
#                    all         33        474      0.713       0.81      0.809      0.378
# Speed: 0.2ms preprocess, 12.8ms inference, 0.0ms loss, 2.4ms postprocess per image
# Results saved to runs/detect/train5
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %% [markdown]
# # Revisión y descargas

# %%
# !yolo predict model='/content/runs/detect/train13/weights/best.pt' source='/content/drive/MyDrive/Paulo/cydia_44/cydia_44/12.jpeg' conf=0.9
# Out:
# /bin/bash: line 1: yolo: command not found

# %%
# !zip -r "/content/drive/MyDrive/Datasets/entrenamientos_yyyyt" "/content/runs"
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/detect/ (stored 0%)
#   adding: content/runs/detect/predict3/ (stored 0%)
#   adding: content/runs/detect/predict3/12.jpeg (deflated 3%)
#   adding: content/runs/detect/train4/ (stored 0%)
#   adding: content/runs/detect/train4/weights/ (stored 0%)
#   adding: content/runs/detect/train4/labels_correlogram.jpg (deflated 38%)
#   adding: content/runs/detect/train4/events.out.tfevents.1701740590.d70229794502.4796.0 (deflated 94%)
#   adding: content/runs/detect/train4/args.yaml (deflated 51%)
#   adding: content/runs/detect/train4/labels.jpg (deflated 27%)
#   adding: content/runs/detect/train12/ (stored 0%)
#   adding: content/runs/detect/train12/weights/ (stored 0%)
#   adding: content/runs/detect/train12/events.out.tfevents.1701746526.d70229794502.29892.0 (deflated 94%)
#   adding: content/runs/detect/train12/labels_correlogram.jpg (deflated 38%)
#   adding: content/runs/detect/train12/args.yaml (deflated 51%)
#   adding: content/runs/detect/train12/labels.jpg (deflated 27%)
#   adding: content/runs/detect/predict6/ (stored 0%)
#   adding: content/runs/detect/predict6/12.jpeg (deflated 3%)
#   adding: content/runs/detect/train5/ (stored 0%)
#   adding: content/runs/detect/train5/PR_curve.png (deflated 21%)
#   adding: content/runs/detect/train5/P_curve.png (deflated 17%)
#   adding: content/runs/detect/train5/train_batch180.jpg (deflated 10%)
#   adding: content/runs/detect/train5/train_batch1.jpg (deflated 4%)
#   adding: content/runs/detect/train5/R_curve.png (deflated 17%)
#   adding: content/runs/detect/train5/F1_curve.png (deflated 17%)
#   adding: content/runs/detect/train5/train_batch2.jpg (deflated 3%)
#   adding: content/runs/detect/train5/val_batch0_pred.jpg (deflated 4%)
#   adding: content/runs/detect/train5/train_batch0.jpg (deflated 4%)
#   adding: content/runs/detect/train5/val_batch1_labels.jpg (deflated 8%)
#   adding: content/runs/detect/train5/train_batch181.jpg (deflated 8%)
#   adding: content/runs/detect/train5/val_batch0_labels.jpg (deflated 5%)
#   adding: content/runs/detect/train5/weights/ (stored 0%)
#   adding: content/runs/detect/train5/weights/best.pt (deflated 8%)
#   adding: content/runs/detect/train5/weights/last.pt (deflated 8%)
#   adding: content/runs/detect/train5/results.png (deflated 6%)
#   adding: content/runs/detect/train5/val_batch1_pred.jpg (deflated 7%)
#   adding: content/runs/detect/train5/labels_correlogram.jpg (deflated 38%)
#   adding: content/runs/detect/train5/results.csv (deflated 84%)
#   adding: content/runs/detect/train5/train_batch182.jpg (deflated 13%)
#   adding: content/runs/detect/train5/confusion_matrix_normalized.png (deflated 34%)
#   adding: content/runs/detect/train5/args.yaml (deflated 51%)
#   adding: content/runs/detect/train5/events.out.tfevents.1701740649.d70229794502.5095.0 (deflated 93%)
#   adding: content/runs/detect/train5/labels.jpg (deflated 27%)
#   adding: content/runs/detect/train5/confusion_matrix.png (deflated 35%)
#   adding: content/runs/detect/train11/ (stored 0%)
#   adding: content/runs/detect/train11/events.out.tfevents.1701746383.d70229794502.29261.0 (deflated 94%)
#   adding: content/runs/detect/train11/weights/ (stored 0%)
#   adding: content/runs/detect/train11/labels_correlogram.jpg (deflated 38%)
#   adding: content/runs/detect/train11/args.yaml (deflated 51%)
#   adding: content/runs/detect/train11/labels.jpg (deflated 27%)
#   adding: content/runs/detect/predict/ (stored 0%)
#   adding: content/runs/detect/predict/12.jpeg (deflated 3%)
#   adding: content/runs/detect/train/ (stored 0%)
#   adding: content/runs/detect/train/weights/ (stored 0%)
#   adding: content/runs/detect/train/args.yaml (deflated 51%)
#   adding: content/runs/detect/predict5/ (stored 0%)
#   adding: content/runs/detect/predict5/12.jpeg (deflated 3%)
#   adding: content/runs/detect/train3/ (stored 0%)
#   adding: content/runs/detect/train3/PR_curve.png (deflated 27%)
#   adding: content/runs/detect/train3/P_curve.png (deflated 24%)
#   adding: content/runs/detect/train3/train_batch1.jpg (deflated 4%)
#   adding: content/runs/detect/train3/R_curve.png (deflated 25%)
#   adding: content/runs/detect/train3/F1_curve.png (deflated 30%)
#   adding: content/runs/detect/train3/train_batch2.jpg (deflated 3%)
#   adding: content/runs/detect/train3/val_batch0_pred.jpg (deflated 8%)
#   adding: content/runs/detect/train3/events.out.tfevents.1701740316.d70229794502.3279.0 (deflated 94%)
#   adding: content/runs/detect/train3/train_batch0.jpg (deflated 4%)
#   adding: content/runs/detect/train3/val_batch1_labels.jpg (deflated 8%)
#   adding: content/runs/detect/train3/val_batch0_labels.jpg (deflated 5%)
#   adding: content/runs/detect/train3/weights/ (stored 0%)
#   adding: content/runs/detect/train3/weights/best.pt (deflated 9%)
#   adding: content/runs/detect/train3/weights/last.pt (deflated 9%)
#   adding: content/runs/detect/train3/results.png (deflated 21%)
#   adding: content/runs/detect/train3/val_batch1_pred.jpg (deflated 9%)
#   adding: content/runs/detect/train3/labels_correlogram.jpg (deflated 38%)
#   adding: content/runs/detect/train3/results.csv (deflated 72%)
#   adding: content/runs/detect/train3/confusion_matrix_normalized.png (deflated 36%)
#   adding: content/runs/detect/train3/args.yaml (deflated 51%)
#   adding: content/runs/detect/train3/labels.jpg (deflated 27%)
#   adding: content/runs/detect/train3/confusion_matrix.png (deflated 37%)
#   adding: content/runs/detect/predict4/ (stored 0%)
#   adding: content/runs/detect/predict4/12.jpeg (deflated 3%)
#   adding: content/runs/detect/train10/ (stored 0%)
#   adding: content/runs/detect/train10/PR_curve.png (deflated 21%)
#   adding: content/runs/detect/train10/P_curve.png (deflated 25%)
#   adding: content/runs/detect/train10/train_batch180.jpg (deflated 9%)
#   adding: content/runs/detect/train10/train_batch1.jpg (deflated 3%)
#   adding: content/runs/detect/train10/R_curve.png (deflated 21%)
#   adding: content/runs/detect/train10/F1_curve.png (deflated 21%)
#   adding: content/runs/detect/train10/train_batch2.jpg (deflated 3%)
#   adding: content/runs/detect/train10/events.out.tfevents.1701745436.d70229794502.25193.0 (deflated 92%)
#   adding: content/runs/detect/train10/val_batch0_pred.jpg (deflated 2%)
#   adding: content/runs/detect/train10/train_batch0.jpg (deflated 3%)
#   adding: content/runs/detect/train10/val_batch1_labels.jpg (deflated 5%)
#   adding: content/runs/detect/train10/train_batch181.jpg (deflated 7%)
#   adding: content/runs/detect/train10/val_batch0_labels.jpg (deflated 2%)
#   adding: content/runs/detect/train10/weights/ (stored 0%)
#   adding: content/runs/detect/train10/weights/best.pt (deflated 10%)
#   adding: content/runs/detect/train10/weights/last.pt (deflated 10%)
#   adding: content/runs/detect/train10/results.png (deflated 7%)
#   adding: content/runs/detect/train10/val_batch1_pred.jpg (deflated 5%)
#   adding: content/runs/detect/train10/labels_correlogram.jpg (deflated 38%)
#   adding: content/runs/detect/train10/results.csv (deflated 86%)
#   adding: content/runs/detect/train10/train_batch182.jpg (deflated 12%)
#   adding: content/runs/detect/train10/confusion_matrix_normalized.png (deflated 34%)
#   adding: content/runs/detect/train10/args.yaml (deflated 51%)
#   adding: content/runs/detect/train10/labels.jpg (deflated 27%)
#   adding: content/runs/detect/train10/confusion_matrix.png (deflated 35%)
#   adding: content/runs/detect/predict2/ (stored 0%)
#   adding: content/runs/detect/predict2/12.jpeg (deflated 3%)
#   adding: content/runs/detect/train7/ (stored 0%)
#   adding: content/runs/detect/train7/events.out.tfevents.1701742119.d70229794502.11355.0 (deflated 94%)
#   adding: content/runs/detect/train7/weights/ (stored 0%)
#   adding: content/runs/detect/train7/labels_correlogram.jpg (deflated 38%)
#   adding: content/runs/detect/train7/args.yaml (deflated 51%)
#   adding: content/runs/detect/train7/labels.jpg (deflated 27%)
#   adding: content/runs/detect/train9/ (stored 0%)
#   adding: content/runs/detect/train9/train_batch1.jpg (deflated 3%)
#   adding: content/runs/detect/train9/train_batch2.jpg (deflated 3%)
#   adding: content/runs/detect/train9/train_batch0.jpg (deflated 3%)
#   adding: content/runs/detect/train9/weights/ (stored 0%)
#   adding: content/runs/detect/train9/weights/best.pt (deflated 8%)
#   adding: content/runs/detect/train9/weights/last.pt (deflated 8%)
#   adding: content/runs/detect/train9/labels_correlogram.jpg (deflated 38%)
#   adding: content/runs/detect/train9/results.csv (deflated 78%)
#   adding: content/runs/detect/train9/args.yaml (deflated 51%)
#   adding: content/runs/detect/train9/events.out.tfevents.1701745255.d70229794502.24371.0 (deflated 94%)
#   adding: content/runs/detect/train9/labels.jpg (deflated 27%)
#   adding: content/runs/detect/train6/ (stored 0%)
#   adding: content/runs/detect/train6/events.out.tfevents.1701742028.d70229794502.10898.0 (deflated 94%)
#   adding: content/runs/detect/train6/weights/ (stored 0%)
#   adding: content/runs/detect/train6/labels_correlogram.jpg (deflated 38%)
#   adding: content/runs/detect/train6/args.yaml (deflated 51%)
#   adding: content/runs/detect/train6/labels.jpg (deflated 27%)
#   adding: content/runs/detect/train13/ (stored 0%)
#   adding: content/runs/detect/train13/PR_curve.png (deflated 20%)
#   adding: content/runs/detect/train13/P_curve.png (deflated 24%)
#   adding: content/runs/detect/train13/train_batch1.jpg (deflated 4%)
#   adding: content/runs/detect/train13/R_curve.png (deflated 19%)
#   adding: content/runs/detect/train13/train_batch811.jpg (deflated 9%)
#   adding: content/runs/detect/train13/F1_curve.png (deflated 20%)
#   adding: content/runs/detect/train13/train_batch2.jpg (deflated 3%)
#   adding: content/runs/detect/train13/train_batch810.jpg (deflated 12%)
#   adding: content/runs/detect/train13/events.out.tfevents.1701746632.d70229794502.30379.0 (deflated 91%)
#   adding: content/runs/detect/train13/val_batch0_pred.jpg (deflated 5%)
#   adding: content/runs/detect/train13/train_batch0.jpg (deflated 4%)
#   adding: content/runs/detect/train13/train_batch812.jpg (deflated 11%)
#   adding: content/runs/detect/train13/val_batch1_labels.jpg (deflated 8%)
#   adding: content/runs/detect/train13/val_batch0_labels.jpg (deflated 5%)
#   adding: content/runs/detect/train13/weights/ (stored 0%)
#   adding: content/runs/detect/train13/weights/best.pt (deflated 8%)
#   adding: content/runs/detect/train13/weights/last.pt (deflated 8%)
#   adding: content/runs/detect/train13/results.png (deflated 7%)
#   adding: content/runs/detect/train13/val_batch1_pred.jpg (deflated 8%)
#   adding: content/runs/detect/train13/labels_correlogram.jpg (deflated 38%)
#   adding: content/runs/detect/train13/results.csv (deflated 85%)
#   adding: content/runs/detect/train13/confusion_matrix_normalized.png (deflated 34%)
#   adding: content/runs/detect/train13/args.yaml (deflated 51%)
#   adding: content/runs/detect/train13/labels.jpg (deflated 27%)
#   adding: content/runs/detect/train13/confusion_matrix.png (deflated 35%)
#   adding: content/runs/detect/train8/ (stored 0%)
#   adding: content/runs/detect/train8/PR_curve.png (deflated 20%)
#   adding: content/runs/detect/train8/train_batch1262.jpg (deflated 9%)
#   adding: content/runs/detect/train8/P_curve.png (deflated 24%)
#   adding: content/runs/detect/train8/train_batch1260.jpg (deflated 8%)
#   adding: content/runs/detect/train8/train_batch1.jpg (deflated 4%)
#   adding: content/runs/detect/train8/R_curve.png (deflated 20%)
#   adding: content/runs/detect/train8/F1_curve.png (deflated 20%)
#   adding: content/runs/detect/train8/train_batch2.jpg (deflated 3%)
#   adding: content/runs/detect/train8/val_batch0_pred.jpg (deflated 5%)
#   adding: content/runs/detect/train8/train_batch0.jpg (deflated 4%)
#   adding: content/runs/detect/train8/val_batch1_labels.jpg (deflated 8%)
#   adding: content/runs/detect/train8/val_batch0_labels.jpg (deflated 5%)
#   adding: content/runs/detect/train8/train_batch1261.jpg (deflated 12%)
#   adding: content/runs/detect/train8/weights/ (stored 0%)
#   adding: content/runs/detect/train8/weights/best.pt (deflated 8%)
#   adding: content/runs/detect/train8/weights/last.pt (deflated 8%)
#   adding: content/runs/detect/train8/results.png (deflated 7%)
#   adding: content/runs/detect/train8/val_batch1_pred.jpg (deflated 8%)
#   adding: content/runs/detect/train8/events.out.tfevents.1701742191.d70229794502.11706.0 (deflated 89%)
#   adding: content/runs/detect/train8/labels_correlogram.jpg (deflated 38%)
#   adding: content/runs/detect/train8/results.csv (deflated 86%)
#   adding: content/runs/detect/train8/confusion_matrix_normalized.png (deflated 35%)
#   adding: content/runs/detect/train8/args.yaml (deflated 51%)
#   adding: content/runs/detect/train8/labels.jpg (deflated 27%)
#   adding: content/runs/detect/train8/confusion_matrix.png (deflated 35%)
#   adding: content/runs/detect/train2/ (stored 0%)
#   adding: content/runs/detect/train2/PR_curve.png (deflated 29%)
#   adding: content/runs/detect/train2/P_curve.png (deflated 24%)
#   adding: content/runs/detect/train2/train_batch1.jpg (deflated 3%)
#   adding: content/runs/detect/train2/events.out.tfevents.1701740052.d70229794502.2097.0 (deflated 94%)
#   adding: content/runs/detect/train2/R_curve.png (deflated 29%)
#   adding: content/runs/detect/train2/F1_curve.png (deflated 31%)
#   adding: content/runs/detect/train2/train_batch2.jpg (deflated 3%)
#   adding: content/runs/detect/train2/val_batch0_pred.jpg (deflated 7%)
#   adding: content/runs/detect/train2/train_batch0.jpg (deflated 3%)
#   adding: content/runs/detect/train2/val_batch0_labels.jpg (deflated 5%)
#   adding: content/runs/detect/train2/weights/ (stored 0%)
#   adding: content/runs/detect/train2/weights/best.pt (deflated 9%)
#   adding: content/runs/detect/train2/weights/last.pt (deflated 9%)
#   adding: content/runs/detect/train2/results.png (deflated 21%)
#   adding: content/runs/detect/train2/labels_correlogram.jpg (deflated 40%)
#   adding: content/runs/detect/train2/results.csv (deflated 72%)
#   adding: content/runs/detect/train2/confusion_matrix_normalized.png (deflated 36%)
#   adding: content/runs/detect/train2/args.yaml (deflated 51%)
#   adding: content/runs/detect/train2/labels.jpg (deflated 31%)
#   adding: content/runs/detect/train2/confusion_matrix.png (deflated 36%)
